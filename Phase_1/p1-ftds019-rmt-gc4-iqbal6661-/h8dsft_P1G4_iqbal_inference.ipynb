# %%
import pandas as pd
import joblib
import pickle
import json

# %%
with open ('pca.pkl', 'rb') as file_1:
    pca10 = pickle.load(file_1)
with open ('kmeans.pkl', 'rb') as file_2:
    km = pickle.load(file_2)

with open ('winsoriser.pkl', 'rb') as file_3:
    winsoriser = pickle.load(file_3)
with open ('scaler.pkl','rb') as file_4:
    scaler = pickle.load(file_4)

# %% [markdown]
# # 11. Model Inferences

# %%
data_inferences = pd.read_csv('h8dsft_P1G4_iqbal.csv')

# %%
data_inferences = data_inferences.head(10)

# %%
df = data_inferences.copy()

# %%
data_inferences
# Out:
#    CUST_ID     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     3091    3.833185           0.125000      45.00             45.00
# 1     5069    0.000000           0.000000     176.03            176.03
# 2     6075  757.964752           0.875000     157.40            157.40
# 3     6291  264.566591           0.375000    1150.00           1150.00
# 4     7755  440.613643           1.000000     600.00            600.00
# 5     8299  611.561026           1.000000     765.00            765.00
# 6     8629    0.228572           0.125000      60.00             60.00
# 7     8805  105.333584           0.375000     306.00            306.00
# 8        7   16.379412           0.454545     178.15              0.00
# 9       91  559.151424           1.000000      94.00             94.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    0.00           0.0                0.125
# 1                    0.00           0.0                0.125
# ...

# %%
median_value = data_inferences['MINIMUM_PAYMENTS'].median()

# %%
data_inferences['MINIMUM_PAYMENTS'].fillna(median_value, inplace=True)

# %%
data_inferences
# Out:
#    CUST_ID     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     3091    3.833185           0.125000      45.00             45.00
# 1     5069    0.000000           0.000000     176.03            176.03
# 2     6075  757.964752           0.875000     157.40            157.40
# 3     6291  264.566591           0.375000    1150.00           1150.00
# 4     7755  440.613643           1.000000     600.00            600.00
# 5     8299  611.561026           1.000000     765.00            765.00
# 6     8629    0.228572           0.125000      60.00             60.00
# 7     8805  105.333584           0.375000     306.00            306.00
# 8        7   16.379412           0.454545     178.15              0.00
# 9       91  559.151424           1.000000      94.00             94.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    0.00           0.0                0.125
# 1                    0.00           0.0                0.125
# ...

# %%
data_inferences.drop('CUST_ID' ,inplace=True, axis=1)

# %%
data_inferences=scaler.transform(data_inferences)

# %%
data_inferences=pca10.transform(data_inferences)
# Out:
# c:\Users\maddi\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(

# %%
cluster =km.predict(data_inferences)

# %%
df
# Out:
#    CUST_ID     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     3091    3.833185           0.125000      45.00             45.00
# 1     5069    0.000000           0.000000     176.03            176.03
# 2     6075  757.964752           0.875000     157.40            157.40
# 3     6291  264.566591           0.375000    1150.00           1150.00
# 4     7755  440.613643           1.000000     600.00            600.00
# 5     8299  611.561026           1.000000     765.00            765.00
# 6     8629    0.228572           0.125000      60.00             60.00
# 7     8805  105.333584           0.375000     306.00            306.00
# 8        7   16.379412           0.454545     178.15              0.00
# 9       91  559.151424           1.000000      94.00             94.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    0.00           0.0                0.125
# 1                    0.00           0.0                0.125
# ...

# %%
df['cluster'] = cluster

# %%
df
# Out:
#    CUST_ID     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     3091    3.833185           0.125000      45.00             45.00
# 1     5069    0.000000           0.000000     176.03            176.03
# 2     6075  757.964752           0.875000     157.40            157.40
# 3     6291  264.566591           0.375000    1150.00           1150.00
# 4     7755  440.613643           1.000000     600.00            600.00
# 5     8299  611.561026           1.000000     765.00            765.00
# 6     8629    0.228572           0.125000      60.00             60.00
# 7     8805  105.333584           0.375000     306.00            306.00
# 8        7   16.379412           0.454545     178.15              0.00
# 9       91  559.151424           1.000000      94.00             94.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    0.00           0.0                0.125
# 1                    0.00           0.0                0.125
# ...

# %% [markdown]
# # 12. Kesimpulan

# %% [markdown]
# ## EDA

# %% [markdown]
# * jumlah limit yang harus ditanggung perusahaan sebesar :  20114581.868687
# * BALANCE terbanyak yang dimiliki customer sebanyak : 18495.55855

# %% [markdown]
# ## Cluster

# %% [markdown]
# Cluster 0 (Low Activity):
#
# Menawarkan program rewards atau cashback untuk mendorong penggunaan kartu kredit lebih aktif.
# Menyediakan penawaran khusus atau diskon untuk transaksi pembelian pertama bagi pengguna dalam cluster ini.
# Mengirimkan pemberitahuan atau pengingat secara teratur tentang keuntungan dan manfaat penggunaan kartu kredit.
#
# Cluster 1 (Moderate Activity):
#
# Menawarkan program rewards yang lebih menarik dengan tingkat pengembalian yang lebih tinggi untuk mendorong penggunaan kartu kredit lebih sering.
# Menyediakan penawaran khusus untuk pembelian produk atau layanan yang sering dilakukan oleh pengguna dalam cluster ini.
# Mengirimkan penawaran eksklusif kepada pengguna yang aktif dalam menggunakan kartu kredit mereka.
#
# Cluster 2 (High Cash Advance):
#
# Menawarkan program pinjaman tunai dengan suku bunga yang kompetitif untuk mengurangi kebutuhan pengguna dalam cluster ini untuk melakukan penarikan tunai melalui kartu kredit.
# Memberikan penawaran atau insentif khusus untuk mengurangi penggunaan fitur penarikan tunai dan mendorong penggunaan kartu kredit untuk pembelian langsung.
#
# Cluster 3 (High Usage & Payments):
#
# Menawarkan program rewards yang berfokus pada kategori pembelian yang sering dilakukan oleh pengguna dalam cluster ini.
# Memberikan penawaran khusus atau diskon untuk transaksi pembelian besar yang sering dilakukan oleh pengguna dalam cluster ini.
# Menyediakan layanan pelanggan yang unggul untuk memberikan pengalaman yang lebih baik kepada pengguna dalam cluster ini.
#
# Cluster 4 (Low Purchase & Payments):
#
# Menawarkan program rewards dengan tingkat pengembalian yang lebih tinggi untuk mendorong penggunaan kartu kredit dalam transaksi pembelian.
# Memberikan penawaran khusus atau diskon untuk transaksi pembelian pertama bagi pengguna dalam cluster ini untuk mendorong aktivitas pembelian.
# Mengirimkan pemberitahuan atau pengingat tentang keuntungan dan manfaat penggunaan kartu kredit untuk pembelian produk atau layanan.
